# %%
from __future__ import division
import os
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd 
import gspread
from google.oauth2.service_account import Credentials
from celery import Celery
import io
import math
from io import BytesIO
from PIL import Image
import base64 
from celery.utils.log import get_task_logger
import os
import shutil

logger = get_task_logger(__name__)

# %%
INPUT_FILE = './countries.csv'
path = './'
image_ext = '.png'

df = pd.read_csv(INPUT_FILE)
countries = dict(zip(df.Country.str.lower(), df.l2.str.lower()))

scopes = [
    'https://www.googleapis.com/auth/spreadsheets',
    'https://www.googleapis.com/auth/drive'
]
credentials = Credentials.from_service_account_file('service_account.json',scopes=scopes)

gc = gspread.authorize(credentials)

# %%
from webdriver_manager.chrome import ChromeDriverManager

chrome_options = Options()  
chrome_options.add_argument("--headless") 
#chrome_options.add_argument("--no-sandbox"),
#chrome_options.add_argument("--disable-infobars"),# // https://stackoverflow.com/a/43840128/1689770
#chrome_options.add_argument("--disable-dev-shm-usage"),# // https://stackoverflow.com/a/50725918/1689770
#chrome_options.add_argument("--disable-browser-side-navigation"),# // https://stackoverflow.com/a/49123152/1689770
chrome_options.add_argument("--disable-gpu"),# // https://stackoverflow.com/questions/51959986/how-to-solve-selenium-chromedriver-timed-out-receiving-message-from-renderer-exc
#chrome_options.add_argument("--disable-features=VizDisplayCompositor")#  
url = os.environ.get("SELENIUM_SERVER_URL", "http://localhost:4444/wd/hub")
try:
    driver = webdriver.Remote(command_executor=url,options=chrome_options)
except Exception as e:
    print("Exception", e)
    driver.quit()

# %%
def _make_query(word,language,country):
    base_url = 'https://www.google.com/search?q='
    query = word.replace(' ','%20')
    lr="&lr=lang_xx".replace('xx',language.lower())
    cr="&cr=countryXX".replace('XX',country.upper())
    hl="&hl=xx".replace('xx',language.lower())
    return base_url+query+lr+cr+hl

# %%
def long_slice(img, slice_size = 1080):
    logger.info('long_slice')
    """slice an image into parts slice_size tall"""
    width, height = img.size
    upper = 0
    left = 0
    slices = int(math.ceil(height/slice_size))

    count = 1
    im_slices = []
    for _ in range(slices):
        #if we are at the end, set the lower bound to be the bottom of the image
        if count == slices:
            lower = height
        else:
            lower = int(count * slice_size)  

        bbox = (left, upper, width, lower)
        working_slice = img.crop(bbox)
        upper += slice_size
        #save the slice
        im_slices.append(working_slice)
        count +=1
    
    return im_slices

# %%
from PIL import Image
import io

def image_to_byte_array(image: Image):
    buffer = io.BytesIO()
    image.save(buffer, format='png')
    return buffer

# %%
def get_screenshot_pil(driver, link):
    driver.get(link)
    S = lambda X: driver.execute_script('return document.body.parentNode.scroll'+X)
    driver.set_window_size(S('Width'),S('Height')) # May need manual adjustment
    screen_base64 = driver.find_element(by=By.TAG_NAME, value='body').screenshot_as_base64
    image = Image.open(io.BytesIO(base64.decodebytes(bytes(screen_base64, "utf-8"))))
    return image

# %%
def crawl(task_id,link,language,country,driver, df):
    images = {}
    for index, row in df.iterrows():
        word = row['Words'].strip()
        images[word] = {}
        link = _make_query(word,language,country)
        image = get_screenshot_pil(driver, link)
        im_slices = long_slice(image)
        print(index, link, len(im_slices))
        
        #images_dir = f'./screenshots/{task_id}/{word}/{language}/{country}/'
        #os.makedirs(os.path.dirname(images_dir), exist_ok=True)
        
        for slice_ind, aslice in enumerate(im_slices):
            image_name = 'Images'+str(slice_ind)+image_ext
            images[word][image_name] = image_to_byte_array(aslice)
            #image_path = images_dir+image_name
            #aslice.save(image_path)
            df.at[index, image_name] = '' # aslice #str(image_path)
    #worksheet.update([df.columns.values.tolist()] + df.values.tolist())
    
    return (df,images)
    # ==== DELETING 
    #logger.info("Done")
    #shutil.rmtree('./screenshots/{task_id}/')
    
    #driver.quit()    
    #return True

# %%
link = 'https://docs.google.com/spreadsheets/d/1V6I9IvHQpsKr_xw2sVV5dOGxq4WeifKSOe-iM3M5RZ8/edit#gid=0'
sh = gc.open_by_url(link)
worksheet = sh.get_worksheet(0)
df = pd.DataFrame(worksheet.get_all_records())

df_output, images = crawl(
    task_id = 'taskid123',
    link = link,
    language = 'fr',
    country = 'de',
    driver = driver,
    df = df
)
# Out:
# 0 https://www.google.com/search?q=Skirt&lr=lang_fr&cr=countryDE&hl=fr 3
# 1 https://www.google.com/search?q=Bikini&lr=lang_fr&cr=countryDE&hl=fr 3
# 2 https://www.google.com/search?q=Dress%20pants&lr=lang_fr&cr=countryDE&hl=fr 3
# 3 https://www.google.com/search?q=Jumper&lr=lang_fr&cr=countryDE&hl=fr 3
# 4 https://www.google.com/search?q=Sneakers&lr=lang_fr&cr=countryDE&hl=fr 3
# 5 https://www.google.com/search?q=Hoodie&lr=lang_fr&cr=countryDE&hl=fr 3
# 6 https://www.google.com/search?q=Vest&lr=lang_fr&cr=countryDE&hl=fr 3
# 7 https://www.google.com/search?q=High%20heels&lr=lang_fr&cr=countryDE&hl=fr 3
# 8 https://www.google.com/search?q=Flip%20flops&lr=lang_fr&cr=countryDE&hl=fr 3
# 9 https://www.google.com/search?q=Handbag&lr=lang_fr&cr=countryDE&hl=fr 3
# 10 https://www.google.com/search?q=Tank%20top&lr=lang_fr&cr=countryDE&hl=fr 3
# 11 https://www.google.com/search?q=Singlet&lr=lang_fr&cr=countryDE&hl=fr 3
# 12 https://www.google.com/search?q=Boots&lr=lang_fr&cr=countryDE&hl=fr 3
# 13 https://www.google.com/search?q=Shorts&lr=lang_fr&cr=countryDE&hl=fr 3
# 14 https://www.google.com/search?q=Polo%20shirt&lr=lang_fr&cr=countryDE&hl=fr 3
# 15 https://www.google.com/search?q=Umbrella&lr=lang_fr&cr=countryDE&hl=fr 3
# 16 https://www.google.com/search?q=Dress&lr=lang_fr&cr=countryDE&hl=fr 3
# 17 https://www.google.com/search?q=Hawaiian%20shirt&lr=lang_fr&cr=countryDE&hl=fr 3
# 18 https://www.google.com/search?q=Mittens&lr=lang_fr&cr=countryDE&hl=fr 3
# 19 https://www.google.com/search?q=Socks&lr=lang_fr&cr=countryDE&hl=fr 3
# 20 https://www.google.com/search?q=Swimsuit&lr=lang_fr&cr=countryDE&hl=fr 3
# 21 https://www.google.com/search?q=Trench%20coat&lr=lang_fr&cr=countryDE&hl=fr 3
# 22 https://www.google.com/search?q=Winter%20coat&lr=lang_fr&cr=countryDE&hl=fr 3
# 23 https://www.google.com/search?q=Straw%20hat&lr=lang_fr&cr=countryDE&hl=fr 3
# 24 https://www.google.com/search?q=Cap&lr=lang_fr&cr=countryDE&hl=fr 3
# 25 https://www.google.com/search?q=Scarf&lr=lang_fr&cr=countryDE&hl=fr 3
# 26 https://www.google.com/search?q=Sweater&lr=lang_fr&cr=countryDE&hl=fr 3
# 27 https://www.google.com/search?q=Shirt&lr=lang_fr&cr=countryDE&hl=fr 3
# 28 https://www.google.com/search?q=Jeans&lr=lang_fr&cr=countryDE&hl=fr 3
# 29 https://www.google.com/search?q=Gloves&lr=lang_fr&cr=countryDE&hl=fr 3
# 30 https://www.google.com/search?q=Cap&lr=lang_fr&cr=countryDE&hl=fr 3
# 31 https://www.google.com/search?q=Suit&lr=lang_fr&cr=countryDE&hl=fr 3
# 32 https://www.google.com/search?q=Hawaiian%20shirt&lr=lang_fr&cr=countryDE&hl=fr 3
# 33 https://www.google.com/search?q=Singlet&lr=lang_fr&cr=countryDE&hl=fr 3
# 34 https://www.google.com/search?q=Business%20shoes&lr=lang_fr&cr=countryDE&hl=fr 3
# 35 https://www.google.com/search?q=Flip%20flops&lr=lang_fr&cr=countryDE&hl=fr 3
# 36 https://www.google.com/search?q=Shorts&lr=lang_fr&cr=countryDE&hl=fr 3
# 37 https://www.google.com/search?q=Cardigan&lr=lang_fr&cr=countryDE&hl=fr 3
# 38 https://www.google.com/search?q=Jacket&lr=lang_fr&cr=countryDE&hl=fr 3
# 39 https://www.google.com/search?q=Sport%20shoes&lr=lang_fr&cr=countryDE&hl=fr 3
# 40 https://www.google.com/search?q=Bow%20tie&lr=lang_fr&cr=countryDE&hl=fr 3
# 41 https://www.google.com/search?q=Sleeveless%20shirt&lr=lang_fr&cr=countryDE&hl=fr 3
# 42 https://www.google.com/search?q=Vest&lr=lang_fr&cr=countryDE&hl=fr 3
# 43 https://www.google.com/search?q=Long-sleeve%20top&lr=lang_fr&cr=countryDE&hl=fr 3
# 44 https://www.google.com/search?q=Polo%20shirt&lr=lang_fr&cr=countryDE&hl=fr 3
# 45 https://www.google.com/search?q=Jumper&lr=lang_fr&cr=countryDE&hl=fr 3
# 46 https://www.google.com/search?q=Trench%20coat&lr=lang_fr&cr=countryDE&hl=fr 3
# 47 https://www.google.com/search?q=Bathrobe&lr=lang_fr&cr=countryDE&hl=fr 3
# 48 https://www.google.com/search?q=Cargo%20pants&lr=lang_fr&cr=countryDE&hl=fr 3
# 49 https://www.google.com/search?q=Swimsuit&lr=lang_fr&cr=countryDE&hl=fr 3
# 50 https://www.google.com/search?q=Blazer&lr=lang_fr&cr=countryDE&hl=fr 3
# 51 https://www.google.com/search?q=T-shirt&lr=lang_fr&cr=countryDE&hl=fr 3
# 52 https://www.google.com/search?q=Belt&lr=lang_fr&cr=countryDE&hl=fr 3
# 53 https://www.google.com/search?q=Underpants&lr=lang_fr&cr=countryDE&hl=fr 3
# 54 https://www.google.com/search?q=Waistcoat&lr=lang_fr&cr=countryDE&hl=fr 3
# 55 https://www.google.com/search?q=Socks&lr=lang_fr&cr=countryDE&hl=fr 3
# 56 https://www.google.com/search?q=Tie&lr=lang_fr&cr=countryDE&hl=fr 3
# 57 https://www.google.com/search?q=Pullover&lr=lang_fr&cr=countryDE&hl=fr 3
# 58 https://www.google.com/search?q=Umbrella&lr=lang_fr&cr=countryDE&hl=fr 3
# 59 https://www.google.com/search?q=Scarf&lr=lang_fr&cr=countryDE&hl=fr 3
# 60 https://www.google.com/search?q=Sunglasses&lr=lang_fr&cr=countryDE&hl=fr 3
# 61 https://www.google.com/search?q=Glasses&lr=lang_fr&cr=countryDE&hl=fr 3
# 62 https://www.google.com/search?q=Boots&lr=lang_fr&cr=countryDE&hl=fr 3
# 63 https://www.google.com/search?q=Wallet&lr=lang_fr&cr=countryDE&hl=fr 3
# 64 https://www.google.com/search?q=Handbag&lr=lang_fr&cr=countryDE&hl=fr 3
# 65 https://www.google.com/search?q=Watch&lr=lang_fr&cr=countryDE&hl=fr 3
# 66 https://www.google.com/search?q=Wedding%20dress&lr=lang_fr&cr=countryDE&hl=fr 3
# 67 https://www.google.com/search?q=Sweater&lr=lang_fr&cr=countryDE&hl=fr 3
# 68 https://www.google.com/search?q=T-shirt&lr=lang_fr&cr=countryDE&hl=fr 3
# 69 https://www.google.com/search?q=Sheath%20dress&lr=lang_fr&cr=countryDE&hl=fr 3
# 70 https://www.google.com/search?q=Dress&lr=lang_fr&cr=countryDE&hl=fr 3
# 71 https://www.google.com/search?q=Gym%20clothes&lr=lang_fr&cr=countryDE&hl=fr 3
# 72 https://www.google.com/search?q=Bra&lr=lang_fr&cr=countryDE&hl=fr 3
# 73 https://www.google.com/search?q=Tank%20top&lr=lang_fr&cr=countryDE&hl=fr 3
# 74 https://www.google.com/search?q=Shorts&lr=lang_fr&cr=countryDE&hl=fr 3
# 75 https://www.google.com/search?q=Hoodie&lr=lang_fr&cr=countryDE&hl=fr 3
# 76 https://www.google.com/search?q=Jeans&lr=lang_fr&cr=countryDE&hl=fr 3
# 77 https://www.google.com/search?q=Long%20coat&lr=lang_fr&cr=countryDE&hl=fr 3
# 78 https://www.google.com/search?q=Uniform&lr=lang_fr&cr=countryDE&hl=fr 3
# 79 https://www.google.com/search?q=Coat&lr=lang_fr&cr=countryDE&hl=fr 3
# 80 https://www.google.com/search?q=Dress%20pants&lr=lang_fr&cr=countryDE&hl=fr 3
# 81 https://www.google.com/search?q=Swimsuit&lr=lang_fr&cr=countryDE&hl=fr 3
# 82 https://www.google.com/search?q=Long-sleeve%20top&lr=lang_fr&cr=countryDE&hl=fr 3
# 83 https://www.google.com/search?q=Skirt&lr=lang_fr&cr=countryDE&hl=fr 3
# 84 https://www.google.com/search?q=Thong&lr=lang_fr&cr=countryDE&hl=fr 3
# 85 https://www.google.com/search?q=Hat&lr=lang_fr&cr=countryDE&hl=fr 3
# 86 https://www.google.com/search?q=Necklace&lr=lang_fr&cr=countryDE&hl=fr 3
# 87 https://www.google.com/search?q=Ring&lr=lang_fr&cr=countryDE&hl=fr 3
# 88 https://www.google.com/search?q=Earrings&lr=lang_fr&cr=countryDE&hl=fr 3
# 89 https://www.google.com/search?q=Perfume&lr=lang_fr&cr=countryDE&hl=fr 3
# 90 https://www.google.com/search?q=Mittens&lr=lang_fr&cr=countryDE&hl=fr 3
# 91 https://www.google.com/search?q=Sunglasses&lr=lang_fr&cr=countryDE&hl=fr 3
# 92 https://www.google.com/search?q=Handbag&lr=lang_fr&cr=countryDE&hl=fr 3
# 93 https://www.google.com/search?q=Bracelet&lr=lang_fr&cr=countryDE&hl=fr 3
# 94 https://www.google.com/search?q=Purse&lr=lang_fr&cr=countryDE&hl=fr 3
# 95 https://www.google.com/search?q=Watch&lr=lang_fr&cr=countryDE&hl=fr 3
# 96 https://www.google.com/search?q=Umbrella&lr=lang_fr&cr=countryDE&hl=fr 3
# 97 https://www.google.com/search?q=Scarf&lr=lang_fr&cr=countryDE&hl=fr 3
# 98 https://www.google.com/search?q=Slip&lr=lang_fr&cr=countryDE&hl=fr 3
# 99 https://www.google.com/search?q=High-heeled%20shoes&lr=lang_fr&cr=countryDE&hl=fr 3
# 100 https://www.google.com/search?q=Flip-flops&lr=lang_fr&cr=countryDE&hl=fr 3
# 101 https://www.google.com/search?q=Boots&lr=lang_fr&cr=countryDE&hl=fr 3
# 102 https://www.google.com/search?q=Stockings&lr=lang_fr&cr=countryDE&hl=fr 3
# 103 https://www.google.com/search?q=Jacket&lr=lang_fr&cr=countryDE&hl=fr 3
# 104 https://www.google.com/search?q=Overalls&lr=lang_fr&cr=countryDE&hl=fr 3
# 105 https://www.google.com/search?q=Mittens&lr=lang_fr&cr=countryDE&hl=fr 3
# 106 https://www.google.com/search?q=Beanie&lr=lang_fr&cr=countryDE&hl=fr 3
# 107 https://www.google.com/search?q=Baby%20apron&lr=lang_fr&cr=countryDE&hl=fr 3
# 108 https://www.google.com/search?q=Socks&lr=lang_fr&cr=countryDE&hl=fr 3
# 109 https://www.google.com/search?q=Diaper&lr=lang_fr&cr=countryDE&hl=fr 3
# 110 https://www.google.com/search?q=Singlet&lr=lang_fr&cr=countryDE&hl=fr 3
# 111 https://www.google.com/search?q=Shoes&lr=lang_fr&cr=countryDE&hl=fr 3
# 112 https://www.google.com/search?q=Safety%20pin&lr=lang_fr&cr=countryDE&hl=fr 3
# 113 https://www.google.com/search?q=T-shirt&lr=lang_fr&cr=countryDE&hl=fr 3
# 114 https://www.google.com/search?q=Dress&lr=lang_fr&cr=countryDE&hl=fr 3
# 115 https://www.google.com/search?q=Singlet&lr=lang_fr&cr=countryDE&hl=fr 3
# 116 https://www.google.com/search?q=Cap&lr=lang_fr&cr=countryDE&hl=fr 3
# 117 https://www.google.com/search?q=One-piece%20bathing%20suit&lr=lang_fr&cr=countryDE&hl=fr 3
# 118 https://www.google.com/search?q=Hawaiian%20shirt&lr=lang_fr&cr=countryDE&hl=fr 3
# 119 https://www.google.com/search?q=Sunglasses&lr=lang_fr&cr=countryDE&hl=fr 3
# 120 https://www.google.com/search?q=Swim%20trunks&lr=lang_fr&cr=countryDE&hl=fr 3
# 121 https://www.google.com/search?q=Straw%20hat&lr=lang_fr&cr=countryDE&hl=fr 3
# 122 https://www.google.com/search?q=Polo%20shirt&lr=lang_fr&cr=countryDE&hl=fr 3
# 123 https://www.google.com/search?q=Overalls&lr=lang_fr&cr=countryDE&hl=fr 3
# 124 https://www.google.com/search?q=Bikini&lr=lang_fr&cr=countryDE&hl=fr 3
# 125 https://www.google.com/search?q=Shorts&lr=lang_fr&cr=countryDE&hl=fr 3
# 126 https://www.google.com/search?q=Tank%20top&lr=lang_fr&cr=countryDE&hl=fr 3
# 127 https://www.google.com/search?q=Flip%20flops&lr=lang_fr&cr=countryDE&hl=fr 3
# 128 https://www.google.com/search?q=Skirt&lr=lang_fr&cr=countryDE&hl=fr 3
# 129 https://www.google.com/search?q=Bikini&lr=lang_fr&cr=countryDE&hl=fr 3
# 130 https://www.google.com/search?q=Dress%20pants&lr=lang_fr&cr=countryDE&hl=fr 3
# 131 https://www.google.com/search?q=Jumper&lr=lang_fr&cr=countryDE&hl=fr 3
# 132 https://www.google.com/search?q=Sneakers&lr=lang_fr&cr=countryDE&hl=fr 3
# 133 https://www.google.com/search?q=Hoodie&lr=lang_fr&cr=countryDE&hl=fr 3
# 134 https://www.google.com/search?q=Vest&lr=lang_fr&cr=countryDE&hl=fr 3
# 135 https://www.google.com/search?q=High%20heels&lr=lang_fr&cr=countryDE&hl=fr 3
# 136 https://www.google.com/search?q=Flip%20flops&lr=lang_fr&cr=countryDE&hl=fr 3
# 137 https://www.google.com/search?q=Handbag&lr=lang_fr&cr=countryDE&hl=fr 3
# 138 https://www.google.com/search?q=Tank%20top&lr=lang_fr&cr=countryDE&hl=fr 3
# 139 https://www.google.com/search?q=Singlet&lr=lang_fr&cr=countryDE&hl=fr 3
# 140 https://www.google.com/search?q=Boots&lr=lang_fr&cr=countryDE&hl=fr 3
# 141 https://www.google.com/search?q=Shorts&lr=lang_fr&cr=countryDE&hl=fr 3
# 142 https://www.google.com/search?q=Polo%20shirt&lr=lang_fr&cr=countryDE&hl=fr 3
# 143 https://www.google.com/search?q=Umbrella&lr=lang_fr&cr=countryDE&hl=fr 3
# 144 https://www.google.com/search?q=Dress&lr=lang_fr&cr=countryDE&hl=fr 3
# 145 https://www.google.com/search?q=Hawaiian%20shirt&lr=lang_fr&cr=countryDE&hl=fr 3
# 146 https://www.google.com/search?q=Mittens&lr=lang_fr&cr=countryDE&hl=fr 3
# 147 https://www.google.com/search?q=Socks&lr=lang_fr&cr=countryDE&hl=fr 3
# 148 https://www.google.com/search?q=Swimsuit&lr=lang_fr&cr=countryDE&hl=fr 3
# 149 https://www.google.com/search?q=Trench%20coat&lr=lang_fr&cr=countryDE&hl=fr 3
# 150 https://www.google.com/search?q=Winter%20coat&lr=lang_fr&cr=countryDE&hl=fr 3
# 151 https://www.google.com/search?q=Straw%20hat&lr=lang_fr&cr=countryDE&hl=fr 3
# 152 https://www.google.com/search?q=Cap&lr=lang_fr&cr=countryDE&hl=fr 3
# 153 https://www.google.com/search?q=Scarf&lr=lang_fr&cr=countryDE&hl=fr 3
# 154 https://www.google.com/search?q=Sunglasses&lr=lang_fr&cr=countryDE&hl=fr 3
# 155 https://www.google.com/search?q=Apron&lr=lang_fr&cr=countryDE&hl=fr 3
# 156 https://www.google.com/search?q=Necklace&lr=lang_fr&cr=countryDE&hl=fr 3
# 157 https://www.google.com/search?q=Watch&lr=lang_fr&cr=countryDE&hl=fr 3
# 158 https://www.google.com/search?q=Socks&lr=lang_fr&cr=countryDE&hl=fr 3
# 159 https://www.google.com/search?q=Tie&lr=lang_fr&cr=countryDE&hl=fr 3
# 160 https://www.google.com/search?q=Bow%20tie&lr=lang_fr&cr=countryDE&hl=fr 3
# 161 https://www.google.com/search?q=Purse&lr=lang_fr&cr=countryDE&hl=fr 3
# 162 https://www.google.com/search?q=Ring&lr=lang_fr&cr=countryDE&hl=fr 3
# 163 https://www.google.com/search?q=Gloves&lr=lang_fr&cr=countryDE&hl=fr 3
# 164 https://www.google.com/search?q=Scarf&lr=lang_fr&cr=countryDE&hl=fr 3
# 165 https://www.google.com/search?q=Umbrella&lr=lang_fr&cr=countryDE&hl=fr 3
# 166 https://www.google.com/search?q=Boots&lr=lang_fr&cr=countryDE&hl=fr 3
# 167 https://www.google.com/search?q=Mittens&lr=lang_fr&cr=countryDE&hl=fr 3
# 168 https://www.google.com/search?q=Stockings&lr=lang_fr&cr=countryDE&hl=fr 3
# 169 https://www.google.com/search?q=Earmuffs&lr=lang_fr&cr=countryDE&hl=fr 3
# 170 https://www.google.com/search?q=Hair%20clip&lr=lang_fr&cr=countryDE&hl=fr 3
# 171 https://www.google.com/search?q=Hair%20band&lr=lang_fr&cr=countryDE&hl=fr 3
# 172 https://www.google.com/search?q=Safety%20pin&lr=lang_fr&cr=countryDE&hl=fr 3
# 173 https://www.google.com/search?q=Pocket%20watch&lr=lang_fr&cr=countryDE&hl=fr 3
# 174 https://www.google.com/search?q=Beanie&lr=lang_fr&cr=countryDE&hl=fr 3
# 175 https://www.google.com/search?q=Cap&lr=lang_fr&cr=countryDE&hl=fr 3
# 176 https://www.google.com/search?q=Beret&lr=lang_fr&cr=countryDE&hl=fr 3
# 177 https://www.google.com/search?q=Straw%20hat&lr=lang_fr&cr=countryDE&hl=fr 3
# 178 https://www.google.com/search?q=Derby%20hat&lr=lang_fr&cr=countryDE&hl=fr 3
# 179 https://www.google.com/search?q=Helmet&lr=lang_fr&cr=countryDE&hl=fr 3
# 180 https://www.google.com/search?q=Top%20hat&lr=lang_fr&cr=countryDE&hl=fr 3
# 181 https://www.google.com/search?q=Mortar%20board&lr=lang_fr&cr=countryDE&hl=fr 3
# 182 https://www.google.com/search?q=Toner&lr=lang_fr&cr=countryDE&hl=fr 3
# 183 https://www.google.com/search?q=Mirror&lr=lang_fr&cr=countryDE&hl=fr 3
# 184 https://www.google.com/search?q=Brightener&lr=lang_fr&cr=countryDE&hl=fr 3
# 185 https://www.google.com/search?q=Makeup%20kit&lr=lang_fr&cr=countryDE&hl=fr 3
# 186 https://www.google.com/search?q=Nail%20polish&lr=lang_fr&cr=countryDE&hl=fr 3
# 187 https://www.google.com/search?q=Lip%20gloss&lr=lang_fr&cr=countryDE&hl=fr 3
# 188 https://www.google.com/search?q=Lip%20liner&lr=lang_fr&cr=countryDE&hl=fr 3
# 189 https://www.google.com/search?q=Foundation&lr=lang_fr&cr=countryDE&hl=fr 3
# 190 https://www.google.com/search?q=Eyeliner&lr=lang_fr&cr=countryDE&hl=fr 3
# 191 https://www.google.com/search?q=Eye%20shadow&lr=lang_fr&cr=countryDE&hl=fr 3
# 192 https://www.google.com/search?q=Lipstick&lr=lang_fr&cr=countryDE&hl=fr 3
# 193 https://www.google.com/search?q=Mascara&lr=lang_fr&cr=countryDE&hl=fr 3
# 194 https://www.google.com/search?q=Cleanser&lr=lang_fr&cr=countryDE&hl=fr 3
# 195 https://www.google.com/search?q=Tanning%20lotion&lr=lang_fr&cr=countryDE&hl=fr 3
# 196 https://www.google.com/search?q=Bronzer&lr=lang_fr&cr=countryDE&hl=fr 3
# 197 https://www.google.com/search?q=Moisturizer&lr=lang_fr&cr=countryDE&hl=fr 3
# 198 https://www.google.com/search?q=Face%20cream&lr=lang_fr&cr=countryDE&hl=fr 3
# 199 https://www.google.com/search?q=Concealer&lr=lang_fr&cr=countryDE&hl=fr 3
# 200 https://www.google.com/search?q=Primer&lr=lang_fr&cr=countryDE&hl=fr 3
# 201 https://www.google.com/search?q=Blush&lr=lang_fr&cr=countryDE&hl=fr 3
# 202 https://www.google.com/search?q=Brush&lr=lang_fr&cr=countryDE&hl=fr 3
# 203 https://www.google.com/search?q=Perfume&lr=lang_fr&cr=countryDE&hl=fr 3
# 204 https://www.google.com/search?q=Hand%20lotion&lr=lang_fr&cr=countryDE&hl=fr 3
# 205 https://www.google.com/search?q=Razor&lr=lang_fr&cr=countryDE&hl=fr 3
# 206 https://www.google.com/search?q=Tissues&lr=lang_fr&cr=countryDE&hl=fr 3
# 207 https://www.google.com/search?q=Sunglasses&lr=lang_fr&cr=countryDE&hl=fr 3
# 208 https://www.google.com/search?q=Hand%20mirror&lr=lang_fr&cr=countryDE&hl=fr 3
# 209 https://www.google.com/search?q=Wet%20wipe&lr=lang_fr&cr=countryDE&hl=fr 3
# 210 https://www.google.com/search?q=Toothbrush&lr=lang_fr&cr=countryDE&hl=fr 3
# 211 https://www.google.com/search?q=Sunscreen&lr=lang_fr&cr=countryDE&hl=fr 3
# 212 https://www.google.com/search?q=Deodorant&lr=lang_fr&cr=countryDE&hl=fr 3
# 213 https://www.google.com/search?q=Toothpaste&lr=lang_fr&cr=countryDE&hl=fr 3
# 214 https://www.google.com/search?q=Cotton%20swab&lr=lang_fr&cr=countryDE&hl=fr 3
# 215 https://www.google.com/search?q=Tweezers&lr=lang_fr&cr=countryDE&hl=fr 3
# 216 https://www.google.com/search?q=Scissors&lr=lang_fr&cr=countryDE&hl=fr 3
# 217 https://www.google.com/search?q=Mouthwash&lr=lang_fr&cr=countryDE&hl=fr 3
# 218 https://www.google.com/search?q=Dental%20floss&lr=lang_fr&cr=countryDE&hl=fr 3
# 219 https://www.google.com/search?q=Comb&lr=lang_fr&cr=countryDE&hl=fr 3
# 220 https://www.google.com/search?q=Hair%20spray&lr=lang_fr&cr=countryDE&hl=fr 3
# 221 https://www.google.com/search?q=Hair%20clip&lr=lang_fr&cr=countryDE&hl=fr 3
# 222 https://www.google.com/search?q=Hair%20band&lr=lang_fr&cr=countryDE&hl=fr 3
# 223 https://www.google.com/search?q=Hairbrush&lr=lang_fr&cr=countryDE&hl=fr 3
# 224 https://www.google.com/search?q=Bobby%20pin&lr=lang_fr&cr=countryDE&hl=fr 3
# 225 https://www.google.com/search?q=Hair%20dryer&lr=lang_fr&cr=countryDE&hl=fr 3
# 226 https://www.google.com/search?q=Hair%20gel&lr=lang_fr&cr=countryDE&hl=fr 3

# %%
import xlsxwriter
writer_excel = pd.ExcelWriter("bank_summ.xlsx", engine= "xlsxwriter")
df_output.to_excel(writer_excel, index=False, sheet_name= "Sheet1")
workbook = writer_excel.book
worksheet = writer_excel.sheets["Sheet1"]

cell_format = workbook.add_format()
cell_format.set_align('center')
cell_format.set_align('top')

worksheet.set_default_row(400)
worksheet.set_row(0, 20) 
worksheet.set_column("A:A", 20, cell_format)
worksheet.set_column("B:E", 80, cell_format)
#img=Image.open("Money Density.png")
#new_img= img.resize((512,300))
#new_img.save(loc+"new_img.png")
#worksheet.insert_image(1, df.shape[1]+2, loc+"new_img.png")
# Out:
# 0

# %%
cols = df_output.columns.tolist()
row_index = 0
for word, data in images.items():
    row_index += 1
    for image_name, bytearr in data.items():
        col_index = cols.index(image_name)
        img_data =  {'image_data': images[word][image_name],'y_scale':0.5, 'x_scale':0.5}
        worksheet.insert_image(row_index, col_index, image_name, img_data)

# %%
writer_excel.save()

# %%
# OLD
def row_iterator(row, row_index, cols, ws):
    row_index = row_index + 1
    for ind, image_path in enumerate(cols):
        if 'Images' in image_path and isinstance(row[image_path], str):
            col_index = ind +1
            ws.insert_image(row_index, col_index, row[image_path])
            ws.insert_image('B5', 'image.png', {'image_data': image_data, 'x_scale': 0.5, 'y_scale': 0.5})
